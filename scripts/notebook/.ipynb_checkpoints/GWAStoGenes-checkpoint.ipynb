# %% [markdown]
# ### Pulling genes by significant SNPs from multivariate GWAS on Starch and Protein

# %%
.libPaths(c('/home/ssapkot/.conda/envs/r_env_360/lib', .libPaths()))

library(tidyverse)
library(ggplot2)
library(pheatmap)
setwd('/panicle/ssapkot/git_repo/StarchProtein/')
# Out:
# Registered S3 method overwritten by 'rvest':
#   method            from
#   read_xml.response xml2
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.2.1 ──
# ✔ ggplot2 3.2.0     ✔ purrr   0.3.2
# ✔ tibble  2.1.3     ✔ dplyr   0.8.2
# ✔ tidyr   0.8.3     ✔ stringr 1.4.0
# ✔ readr   1.3.1     ✔ forcats 0.4.0
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %% [markdown]
# #### Chromosome 4 significant hits

# %%
### SNPs
snps <- read.csv('results/annotation/sigSNPs/Chr4_sigSNPs.csv', header=T) ##gapit format data only snp position is relevant
snps[,c(1,2,3)]
# Out:
# Warning message in read.table(file = file, header = header, sep = sep, quote = quote, :
# “incomplete final line found by readTableHeader on 'results/annotation/sigSNPs/Chr4_sigSNPs.csv'”
#   SNP         Chromosome Position
# 1 S4_64032725 4          64032725
# 2 S4_59696622 4          59696622
# 3 S4_59484847 4          59484847
# 4 S4_59484885 4          59484885

# %% [markdown]
# #### Chromosome 8 significant range

# %%
### SNPs
print("Significant SNPs list")
snps <- read.csv('results/annotation/sigSNPs/Chr8_sigSNPs.csv', header=T)
snps[,1:3]
print("----------------------------")
print("Range of Significant SNPs")
range <- read.csv('results/annotation/sigSNPs/Chr8_sigSNPs_range.csv', header=T)
range
# Out:
# [1] "Significant SNPs list"
#   SNP         Chromosome Position
# 1 S8_51721062 8          51721062
# 2 S8_51721065 8          51721065
# 3 S8_51726098 8          51726098
# 4 S8_51719704 8          51719704
# 5 S8_51715166 8          51715166
# [1] "----------------------------"
# [1] "Range of Significant SNPs"
#   MarkerName       Chromosome Pos_highest Start    End
# 1 StartProtein_sig 8          51721062    51715166 51726098

# %% [markdown]
# #### Chromosome 10 SNPs

# %%
### SNPs
snps <- read.csv('results/annotation/sigSNPs/Chr10_sigSNPs.csv', header=T)
snps[,1:3]
# Out:
# Warning message in read.table(file = file, header = header, sep = sep, quote = quote, :
# “incomplete final line found by readTableHeader on 'results/annotation/sigSNPs/Chr10_sigSNPs.csv'”
#   SNP          Chromosome Position
# 1 S10_58485513 10         58485513
# 2 S10_58485543 10         58485543
# 3 S10_1565701  10         59484847

# %% [markdown]
# ### Putative genes
# Genes within 1 kb of the SNPs were pull using the Sbv3.1.1 gff files. <br />
# '/panicle/Scripts/putativeGenesForGWAS.py': the python script used to pull the genes. Syntax: #python put...py --gff gff.sqlite_file --info annotation_info.txt --gwas input_file (in gapit gwas format) --distance 1 (in kb) --output file_with_genes
#
# The output file is cut to get just the genes as one text file with one column: cut -f column_name output_file | sort -u (unique) > Chrx_Sobic_genelist.txt. <br />
#
# Convert IDs from sobic to sb or vice-versa: <br />
# '/panicle/Scripts/convertIds.py': the python script to convert gene IDs to desired format.

# %% [markdown]
# ### Gene expression data

# %% [markdown]
# #### Genes near or within significant SNPs

# %%
print("Davidson et. al. GENE EXPRESSION RESULTS")
exp <- read.table('results/expression/GeneExp_TPM_RIKEN.tsv', sep='\t', header=T)
df1 <- read.table('results/annotation/Genes/Chr4_genes_range_SORBI.txt',header=T)
#head(df1)
df2 <- read.table('results/annotation/Genes/Chr8_range_genes_SORBI.txt',header=T)
#head(df2)
df3 <- read.table('results/annotation/Genes/Chr10_genes_range_SORBI.txt',header=T)
#head(df3)
df <- rbind(df1,df2,df3)
dim(df)
exp <- df %>% left_join(exp,by='GeneID')
exp
exp <- exp[-c(5,6),]
#exp <- exp[complete.cases(exp),]
log <- log2(exp[,-c(1,2)])
log[is.na(log)] <- 0 
rownames(log) <- exp[,1]
write.csv(log,'results/expression/RIKEN_GeneExp_sigGenes_range.csv')

pheatmap(log, cluster_rows=T, cluster_cols=T)
# Out:
# [1] "Davidson et. al. GENE EXPRESSION RESULTS"
# [1] 12  1
# Warning message:
# “Column `GeneID` joining factors with different levels, coercing to character vector”
#    GeneID            GeneName          seed spikelet stem
# 1  SORBI_3004G247100 SORBI_3004G247100  14  19       19.0
# 2  SORBI_3004G247200 SORBI_3004G247200  52  88       61.0
# 3  SORBI_3004G247300 SORBI_3004G247300  NA   1        4.0
# 4  SORBI_3004G250600 SORBI_3004G250600 174  31       47.0
# 5  SORBI_3004G301500 NA                 NA  NA         NA
# 6  SORBI_3004G301600 NA                 NA  NA         NA
# 7  SORBI_3008G111500 SORBI_3008G111500  13   9        8.0
# 8  SORBI_3008G111600 SORBI_3008G111600  39  55       76.0
# 9  SORBI_3010G019000 SORBI_3010G019000  22  54       33.0
# 10 SORBI_3010G243900 SORBI_3010G243900  22  35       28.0
# 11 SORBI_3010G244000 SORBI_3010G244000   3   4        4.0
# 12 SORBI_3010G244100 SORBI_3010G244100  NA   7        0.9
# plot without title

# %%
print("RIKEN GENE EXPRESSION RESULTS")
exp <- read.table('results/expression/GeneExp_TPM_RIKEN.tsv', sep='\t', header=T)
df1 <- read.table('results/annotation/Genes/Chr4_1kb_Genes_SORBI.txt',header=T)
#head(df1)
df2 <- read.table('results/annotation/Genes/Chr8_range_genes_SORBI.txt',header=T)
#head(df2)
df3 <- read.table('results/annotation/Genes/Chr10_1kb_genes_SORBI.txt',header=T)
#head(df3)
df <- rbind(df1,df2,df3)
df
dim(df)
exp <- df %>% left_join(exp,by='GeneID')
exp <- exp[-c(6,7),]
exp
#exp <- exp[complete.cases(exp),]
log <- log2(exp[,-c(1,2)])
log[is.na(log)] <- 0 
rownames(log) <- exp[,1]
write.csv(log,'results/expression/RIKEN_GeneExp_log2TPM_AllChr_sigGenes_1kb_8r.csv')


pheatmap(log, cluster_rows=T, cluster_cols=T)
# Out:
# [1] "RIKEN GENE EXPRESSION RESULTS"
#   GeneID
# 1 SORBI_3004G247200
# 2 SORBI_3004G250600
# 3 SORBI_3004G301500
# 4 SORBI_3008G111500
# 5 SORBI_3008G111600
# 6 SORBI_3010G244000
# 7 SORBI_3010G244100
# [1] 7 1
# Warning message:
# “Column `GeneID` joining factors with different levels, coercing to character vector”
#   GeneID            GeneName          seed spikelet stem
# 1 SORBI_3004G247200 SORBI_3004G247200  52  88       61
# 2 SORBI_3004G250600 SORBI_3004G250600 174  31       47
# 3 SORBI_3004G301500 NA                 NA  NA       NA
# 4 SORBI_3008G111500 SORBI_3008G111500  13   9        8
# 5 SORBI_3008G111600 SORBI_3008G111600  39  55       76
# plot without title

# %% [markdown]
# #### Chromosome 4 significant genes and their first interactors
# ##### Davidson et. al Gene Expression result

# %%
df1 <- read.table('results/expression/GeneExp_TPM_Davidson.tsv', sep='\t', header=T)
df2 <- read.table('results/annotation/Genes_interactors/Genes_Interactors_Chr4_1Kb_SORBI.txt',header=T)

exp <- df2 %>% left_join(df1,by='GeneID')
exp <- exp[complete.cases(exp),]
annotation <- as.data.frame(exp[,1])
colnames(annotation) <- 'GeneID'

log <- log2(exp[-c(1,2)])
log[is.na(log)] <- 0 
rownames(log) <- exp$GeneID

pheatmap(log, scale="row", cluster_rows=T, cluster_cols=T)
# Out:
# Warning message:
# “Column `GeneID` joining factors with different levels, coercing to character vector”
# plot without title

# %% [markdown]
# ##### RIKEN Gene Expression result

# %%
df1 <- read.table('results/expression/GeneExp_TPM_RIKEN.tsv', sep='\t', header=T)
df2 <- read.table('results/annotation/Genes_interactors/Genes_Interactors_Chr4_1Kb_SORBI.txt',header=T)

exp <- df2 %>% left_join(df1,by='GeneID')
exp <- exp[complete.cases(exp),]

log <- log2(exp[-c(1,2)])
log[is.na(log)] <- 0 
rownames(log) <- exp$GeneID
pheatmap(log, cluster_rows=T, cluster_cols=T)
# Out:
# Warning message:
# “Column `GeneID` joining factors with different levels, coercing to character vector”
# plot without title

# %% [markdown]
# #### Chromosome 8 significant genes and their first interactors
# Using medium confidenc(0.7 or 700) interactors
# ##### Davidson et. al Gene Expression result

# %%
df1 <- read.table('results/expression/GeneExp_TPM_Davidson.tsv', sep='\t', header=T)
df2 <- read.table('results/annotation/Genes_interactors/Genes_Interactors_Chr8_conf0.7_SORBI.txt',header=T)

exp <- df2 %>% left_join(df1,by='GeneID')
exp <- exp[complete.cases(exp),]
log <- log2(exp[-c(1,2)])
log[is.na(log)] <- 0
rownames(log) <- exp$GeneID
pheatmap(log, cluster_rows=T, cluster_cols=T)
# Out:
# Warning message:
# “Column `GeneID` joining factors with different levels, coercing to character vector”
# plot without title

# %%
df1 <- read.table('results/expression/GeneExp_TPM_RIKEN.tsv', sep='\t', header=T)
df2 <- read.table('results/annotation/Genes_interactors/Genes_Interactors_Chr8_conf0.7_SORBI.txt',header=T)

exp <- df2 %>% left_join(df1,by='GeneID')
exp <- exp[complete.cases(exp),]
log <- log2(exp[-c(1,2)])
log[is.na(log)] <- 0
rownames(log) <- exp$GeneID
pheatmap(log, cluster_rows=T, cluster_cols=T)
# Out:
# Warning message:
# “Column `GeneID` joining factors with different levels, coercing to character vector”
# plot without title

# %% [markdown]
# ### Combining chr 4, 8 and 10 genes and interactors

# %%
#while (!is.null(dev.list()))  dev.off()
df1 <- read.table('results/annotation/Genes_interactors/pub/Chr4_genes_interactors_700_range_SORBI.txt',header=T)
df1 <- unique(df1)
df1$group <- 'Chr4'
df2 <- read.table('results/annotation/Genes_interactors/pub/Chr8_range_GenesInterExpress_700_SORBI.txt',header=T)
df2 <- unique(df2)
df2$group <- 'Chr8'
df3 <- read.table('results/annotation/Genes_interactors/pub/Chr10_genes_interactors_700_range_SORBI.txt',header=T)
df3 <- unique(df3)
df3$group <- 'Chr10'
df4 <- rbind(df1,df2,df3)
head(df4)
dim(df4)
# df <- rbind(df4,df)
# dim(df)


exp <- read.table('results/expression/GeneExp_TPM_RIKEN.tsv', sep='\t', header=T)
exp1 <- df4 %>% left_join(exp, by="GeneID")
exp1 <- exp1[complete.cases(exp1),]
#exp1[is.na(exp1)] <- 1
log <- log2(exp1[,-c(1,2,3)])
rownames(log) <- exp1$GeneID
annotation <- data.frame(exp1[,2])
rownames(annotation) <- rownames(log)
colnames(annotation) <- c('group')
dim(annotation)
log$group <- exp1$group
write.csv(log, 'results/expression/RIKEN_GeneExp_GenesInteractors_range.csv',row.names=TRUE)
dim(log)
#png('results/expression/Heatmap_GeneExp_Chr4_8_GenesInteractors.png', height=900,width=900)
#pheatmap(log, cluster_rows=T, cluster_cols=T, angle_col=45)
#dev.off()
# Out:
#   GeneID            group
# 1 SORBI_3001G209900 Chr4
# 2 SORBI_3001G418500 Chr4
# 3 SORBI_3003G304800 Chr4
# 4 SORBI_3004G247100 Chr4
# 5 SORBI_3004G247200 Chr4
# 6 SORBI_3004G356700 Chr4
# [1] 121   2
# Warning message:
# “Column `GeneID` joining factors with different levels, coercing to character vector”
# [1] 108   1
# [1] 108   4

# %%
### merging all genes and interactors from different chromosomes into one
c4 <- read.table('results/annotation/Genes_interactors/pub/Chr4_genes_interactors_700_range.txt', header=F)
c8 <- read.table('results/annotation/Genes_interactors/Chr8_genes_interactors_700_range.txt', header=F)
c10 <- read.table('results/annotation/Genes_interactors/pub/Chr10_genes_interactors_700_range.txt', header=F)

df.gi <- rbind(c4,c8,c10)
dim(df.gi)
df.g <- unique(df.gi)
dim(df.g)

write.csv(df.g,'results/annotation/Genes_interactors/pub/AllChr_genes_interactors_range_original.txt',row.names=F)
# Out:
# [1] 129   1
# [1] 129   1

# %%
## Making a df with all there sb, sobic, sorbi format for all genes.
df1 <- read.table('results/annotation/Genes_interactors/pub/AllChr_genes_interactors_range_sobic.txt',header=F)
df2 <- read.table('results/annotation/Genes_interactors/pub/AllChr_genes_interactors_range_sobic2sb.txt',header=F)
df <- cbind(df2,df1,df1)
colnames(df) <- c('SbID','SobicID','GeneID')
dim(df)
df
write.csv(df, 'results/annotation/Genes_interactors/pub/Genes_interactors_allFormats.csv',row.names=F)
# Out:
# [1] 125   3
#     SbID          SobicID          GeneID
# 1   Sb01g018560   Sobic.001G209900 Sobic.001G209900
# 2   Sb01g039380   Sobic.001G418500 Sobic.001G418500
# 3   Sb03g035340   Sobic.003G304800 Sobic.003G304800
# 4   Sb04g028700   Sobic.004G247100 Sobic.004G247100
# 5   Sb04g028710   Sobic.004G247200 Sobic.004G247200
# 6   Sb04g038310   Sobic.004G356700 Sobic.004G356700
# 7   Sb06g000390.1 Sobic.006G002201 Sobic.006G002201
# 8   Sb06g001580   Sobic.006G016600 Sobic.006G016600
# 9   Sb06g020460   Sobic.006G124300 Sobic.006G124300
# 10  Sb06g027320   Sobic.006G201400 Sobic.006G201400
# 11  Sb06g030830   Sobic.006G242300 Sobic.006G242300
# 12  Sb08g018340   Sobic.008G131100 Sobic.008G131100
# 13  Sb09g019290   Sobic.009G125400 Sobic.009G125400
# 14  Sb10g026800.1 Sobic.010G222900 Sobic.010G222900
# 15  Sb10g027820   Sobic.010G236600 Sobic.010G236600
# 16  Sb01g000380   Sobic.001G003100 Sobic.001G003100
# 17  Sb01g003070   Sobic.001G032800 Sobic.001G032800
# 18  Sb01g005860   Sobic.001G064500 Sobic.001G064500
# 19  Sb01g007980   Sobic.001G088500 Sobic.001G088500
# 20  Sb01g011310   Sobic.001G129000 Sobic.001G129000
# 21  Sb01g012000   Sobic.001G137400 Sobic.001G137400
# 22  Sb01g012010   Sobic.001G137500 Sobic.001G137500
# 23  Sb01g012020   Sobic.001G137600 Sobic.001G137600
# 24  Sb01g012040   Sobic.001G137800 Sobic.001G137800
# 25  Sb01g013010   Sobic.001G149600 Sobic.001G149600
# 26  Sb01g013840   Sobic.001G158700 Sobic.001G158700
# 27  Sb01g017050   Sobic.001G193500 Sobic.001G193500
# 28  Sb01g020010   Sobic.001G228200 Sobic.001G228200
# 29  Sb07g015140   Sobic.007G108100 Sobic.007G108100
# 30  Sb01g039390   Sobic.001G418600 Sobic.001G418600
# ... ...           ...              ...
# 96  Sb01g009930   Sobic.001G111500 Sobic.001G111500
# 97  Sb01g009930   Sobic.001G111500 Sobic.001G111500
# 98  Sb01g038820   Sobic.001G411400 Sobic.001G411400
# 99  Sb02g032760   Sobic.002G296400 Sobic.002G296400
# 100 Sb02g043020   Sobic.002G418400 Sobic.002G418400
# 101 Sb03g003650   Sobic.003G040900 Sobic.003G040900
# 102 Sb03g005310   Sobic.003G062300 Sobic.003G062300
# 103 Sb03g008660   Sobic.003G103400 Sobic.003G103400
# 104 Sb03g025560   Sobic.003G191700 Sobic.003G191700
# 105 Sb03g029870   Sobic.003G241900 Sobic.003G241900
# 106 Sb03g039750   Sobic.003G355300 Sobic.003G355300
# 107 Sb04g003660   Sobic.004G042200 Sobic.004G042200
# 108 Sb04g006650   Sobic.004G080500 Sobic.004G080500
# 109 Sb04g023680   Sobic.004G188400 Sobic.004G188400
# 110 Sb04g026190   Sobic.004G216700 Sobic.004G216700
# 111 Sb04g030370.1 Sobic.004G265700 Sobic.004G265700
# 112 Sb04g034480   Sobic.004G312600 Sobic.004G312600
# 113 Sb05g020900   Sobic.005G143900 Sobic.005G143900
# 114 Sb05g003660   Sobic.005G044400 Sobic.005G044400
# 115 Sb06g017130   Sobic.006G085300 Sobic.006G085300
# 116 Sb06g018510   Sobic.006G101600 Sobic.006G101600
# 117 Sb07g003870   Sobic.007G047400 Sobic.007G047400
# 118 Sb07g005380   Sobic.007G068000 Sobic.007G068000
# 119 Sb07g027750   Sobic.007G210300 Sobic.007G210300
# 120 Sb09g022380   Sobic.009G161200 Sobic.009G161200
# 121 Sb09g030700   Sobic.009G257300 Sobic.009G257300
# 122 Sb10g010050   Sobic.010G115800 Sobic.010G115800
# 123 Sb10g013750   Sobic.010G138000 Sobic.010G138000
# 124 Sb10g028340   Sobic.010G243900 Sobic.010G243900
# 125 Sb10g028350   Sobic.010G244000 Sobic.010G244000
